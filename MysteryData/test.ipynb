# %%
import numpy as np
import pandas as pd
import sklearn

print("NumPy version:", np.__version__)
print("pandas version:", pd.__version__)
print("scikit-learn version:", sklearn.__version__)
# Out:
# NumPy version: 2.5.2
# pandas version: 3.0.5
# scikit-learn version: 1.9.0

# %%
values=[12,18,15,21,19]
avg = sum(values)/len(values)

print("Average:", avg)
print("Values:", values)
# Out:
# Average: 17.0
# Values: [12, 18, 15, 21, 19]

# %% [markdown]
# ## Initial Analysis
#
# dataset contains 5 observations. The mean is 17.0

# %%
print(max(values))
# Out:
# 21

# %%
temperatures = np.array([68,72,75,71,69])

print("Number of observations:", temperatures.size)
print("Mean:", temperatures.mean())
print("Minimum:", temperatures.min())
print("Maximum:", temperatures.max())

fahrenheit = np.array([32, 50, 68, 86])
celsius = (fahrenheit - 32) * 5 / 9

print(celsius)
# Out:
# Number of observations: 5
# Mean: 71.0
# Minimum: 68
# Maximum: 75
# [ 0. 10. 20. 30.]

# %%
scores = np.array([72, 95, 81, 64, 88, 91])
passing_scores = scores[scores >= 70]

print("Passing scores:", passing_scores)
print("Number passing:", passing_scores.size)
# Out:
# Passing scores: [72 95 81 88 91]
# Number passing: 5

# %%
data = np.array([
[72, 80, 85],
 [90, 88, 93],

 [65, 70, 68]
 ])

print("Shape:", data.shape)
print("First row:", data[0])
print("Second column:", data[:, 1])
print("Column means:", data.mean(axis=0))
# Out:
# Shape: (3, 3)
# First row: [72 80 85]
# Second column: [80 88 70]
# Column means: [75.66666667 79.33333333 82.        ]
